# %% [markdown]
# # **Face Morphing**
#
# ---
#
# ### Face morphing is a technique that involves blending two or more images of faces together in order to create a new image that appears to be a hybrid of the original faces. [Code Source](https://github.com/Azmarie/Face-Morphing/)

# %%
# Import Dependancies
import glob
import os
from os import listdir
import sys
from PIL import Image
import cv2
import imutils 
from imutils import face_utils
import dlib
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import random
import itertools

# %% [markdown]
# ### **Loading Images:** The first step in face morphing is to load the images that we want to blend together. These images should be of the same size and orientation, size is covered by the crop functions but orientation isn't, if you need to align your images you should use an aligning script such as [this one.](https://github.com/Azmarie/Face-Morphing/tree/master/code/utils)

# %%
Carpetas = ['/home/branco/Documentos/Investigacion/scripts/Caras_seleccionadas/ASML', '/home/branco/Documentos/Investigacion/scripts/Caras_seleccionadas/FEI', '/home/branco/Documentos/Investigacion/scripts/Caras_seleccionadas/SMDD']

# %%
# Import Images
images = [cv2.imread(item) for i in [glob.glob(f'../../Caras_seleccionadas/FEI/*.jpg')] for item in i]

# %%
# Image Names as Labels
image_names = [image for image in os.listdir('../../Caras_seleccionadas/FEI/') if image.endswith('.jpg')]

# %%
# Cropping Images
class NoFaceFound(Exception):
   """Raised when there is no face found"""
   pass

# Calculate Image Dimensions
def calculate_margin_help(img1,img2):
    """ 
    Returns dimensions, difference in dimensions and average dimensions of two images.
    """
    # Dimensions of first image
    size1 = img1.shape
    # Dimensions of second image
    size2 = img2.shape
    # Difference in width between images
    diff0 = abs(size1[0]-size2[0])//2
    # Difference in height between images
    diff1 = abs(size1[1]-size2[1])//2
    # Average of width between images
    avg0 = (size1[0]+size2[0])//2
    # Average of height between images
    avg1 = (size1[1]+size2[1])//2

    return [size1,size2,diff0,diff1,avg0,avg1]

# Crop Image
def crop_image(img1,img2):
    # Get image info using margin help function
    [size1,size2,diff0,diff1,avg0,avg1] = calculate_margin_help(img1,img2)

    # Do nothing in case the dimensions of the image match
    if(size1[0] == size2[0] and size1[1] == size2[1]):
        return [img1,img2]

    # Resize second image in case it's bigger than the first image
    elif(size1[0] <= size2[0] and size1[1] <= size2[1]):
        scale0 = size1[0]/size2[0]
        scale1 = size1[1]/size2[1]
        if(scale0 > scale1):
            res = cv2.resize(img2,None,fx=scale0,fy=scale0,interpolation=cv2.INTER_AREA)
        else:
            res = cv2.resize(img2,None,fx=scale1,fy=scale1,interpolation=cv2.INTER_AREA)
        return crop_image_help(img1,res)
    
    # Resize first image in case it's bigger than the second image
    elif(size1[0] >= size2[0] and size1[1] >= size2[1]):
        scale0 = size2[0]/size1[0]
        scale1 = size2[1]/size1[1]
        if(scale0 > scale1):
            res = cv2.resize(img1,None,fx=scale0,fy=scale0,interpolation=cv2.INTER_AREA)
        else:
            res = cv2.resize(img1,None,fx=scale1,fy=scale1,interpolation=cv2.INTER_AREA)
        return crop_image_help(res,img2)

    # In case of a shape mismatch, resize both images to the average of their dimensions
    elif(size1[0] >= size2[0] and size1[1] <= size2[1]):
        return [img1[diff0:avg0,:],img2[:,-diff1:avg1]]
    else:
        return [img1[:,diff1:avg1],img2[-diff0:avg0,:]]

# Crop Image Helper Function
def crop_image_help(img1,img2):
    # Get image info using margin help function
    [size1,size2,diff0,diff1,avg0,avg1] = calculate_margin_help(img1,img2)
    
    # If the dimensions match, do nothing
    if(size1[0] == size2[0] and size1[1] == size2[1]):
        return [img1,img2]

    # If the dimensions don't match, crop as necessary
    elif(size1[0] <= size2[0] and size1[1] <= size2[1]):
        return [img1,img2[-diff0:avg0,-diff1:avg1]]

    elif(size1[0] >= size2[0] and size1[1] >= size2[1]):
        return [img1[diff0:avg0,diff1:avg1],img2]

    elif(size1[0] >= size2[0] and size1[1] <= size2[1]):
        return [img1[diff0:avg0,:],img2[:,-diff1:avg1]]

    else:
        return [img1[:,diff1:avg1],img2[diff0:avg0,:]]

# %% [markdown]
# ### **Locate Facial Landmarks:** Next, we need to locate the facial landmarks in each image. This can be done using various methods such as using a pre-trained facial landmark detector or training a custom landmark detector. The landmark points should be consistent across all images, as they will be used to define the correspondences between the images. For this task dlib was used with a [pre-trained model](https://github.com/davisking/dlib-models) loaded. The model is also available on my Google Drive linked at the end of the notebook.

# %%
# Locate Facial Landmarks
def generate_face_correspondences(theImage1, theImage2):
    # Detect the points of face.
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')
    corresp = np.zeros((68,2))
    
    imgList = crop_image(theImage1,theImage2)
    list1 = []
    list2 = []
    j = 1

    for img in imgList:

        size = (img.shape[0],img.shape[1])
        if(j == 1):
            currList = list1
        else:
            currList = list2

        # Ask the detector to find the bounding boxes of each face. The 1 in the
        # second argument indicates that we should upsample the image 1 time. This
        # will make everything bigger and allow us to detect more faces.

        dets = detector(img, 1)

        try:
            if len(dets) == 0:
                raise NoFaceFound
        except NoFaceFound:
            print("Sorry, but I couldn't find a face in the image.")

        j=j+1

        for k, rect in enumerate(dets):
            
            # Get the landmarks/parts for the face in rect.
            shape = predictor(img, rect)
            # corresp = face_utils.shape_to_np(shape)
            
            for i in range(0,68):
                x = shape.part(i).x
                y = shape.part(i).y
                currList.append((x, y))
                corresp[i][0] += x
                corresp[i][1] += y
                # cv2.circle(img, (x, y), 2, (0, 255, 0), 2)

            # Add back the background
            currList.append((1,1))
            currList.append((size[1]-1,1))
            currList.append(((size[1]-1)//2,1))
            currList.append((1,size[0]-1))
            currList.append((1,(size[0]-1)//2))
            currList.append(((size[1]-1)//2,size[0]-1))
            currList.append((size[1]-1,size[0]-1))
            currList.append(((size[1]-1),(size[0]-1)//2))

    # Add back the background
    narray = corresp/2
    narray = np.append(narray,[[1,1]],axis=0)
    narray = np.append(narray,[[size[1]-1,1]],axis=0)
    narray = np.append(narray,[[(size[1]-1)//2,1]],axis=0)
    narray = np.append(narray,[[1,size[0]-1]],axis=0)
    narray = np.append(narray,[[1,(size[0]-1)//2]],axis=0)
    narray = np.append(narray,[[(size[1]-1)//2,size[0]-1]],axis=0)
    narray = np.append(narray,[[size[1]-1,size[0]-1]],axis=0)
    narray = np.append(narray,[[(size[1]-1),(size[0]-1)//2]],axis=0)
    
    return [size,imgList[0],imgList[1],list1,list2,narray]

# %% [markdown]
# ### **Create a Triangulation:** The next step is to create a triangulation of the facial landmarks. A Delaunay triangulation is typically used, which involves creating a mesh of triangles that covers the entire face. The triangulation will be used to warp and blend the images together.

# %%
# Check if a point is inside a rectangle
def rect_contains(rect, point):

    if point[0] < rect[0]:
        return False
    elif point[1] < rect[1]:
        return False
    elif point[0] > rect[2]:
        return False
    elif point[1] > rect[3]:
        return False
    return True

# Write the delaunay triangles into a file
def draw_delaunay(f_w, f_h, subdiv, dictionary1):

    list4 = []

    triangleList = subdiv.getTriangleList()
    r = (0, 0, f_w, f_h)

    for t in triangleList :
        pt1 = (int(t[0]), int(t[1]))
        pt2 = (int(t[2]), int(t[3]))
        pt3 = (int(t[4]), int(t[5]))

        if rect_contains(r, pt1) and rect_contains(r, pt2) and rect_contains(r, pt3) :
            list4.append((dictionary1[pt1],dictionary1[pt2],dictionary1[pt3]))

    dictionary1 = {}
    return list4

# Triangulate
def make_delaunay(f_w, f_h, theList, img1, img2):

    # Make a rectangle.
    rect = (0, 0, f_w, f_h)

    # Create an instance of Subdiv2D.
    subdiv = cv2.Subdiv2D(rect)

    # Make a points list and a searchable dictionary. 
    theList = theList.tolist()
    points = [(int(x[0]),int(x[1])) for x in theList]
    dictionary = {x[0]:x[1] for x in list(zip(points, range(76)))}
    
    # Insert points into subdiv
    for p in points :
        subdiv.insert(p)

    # Make a delaunay triangulation list.
    list4 = draw_delaunay(f_w, f_h, subdiv, dictionary)
   
    # Return the list.
    return list4

# %% [markdown]
# ### **Calculate the Affine Transformations:** Using the triangulation, we can calculate the affine transformations that will be used to warp the images. Each triangle in one image will be warped to the corresponding triangle in the other image. The affine transformations can be calculated using the set of corresponding points in each triangle.
#
# ### **Warp the Images:** Once the affine transformations have been calculated, we can warp each triangle in one image to its corresponding triangle in the other image. This involves applying the affine transformation to each pixel in the triangle to find its corresponding location in the other image. The pixels are then blended together using a weighted average based on the distance between the pixels and the vertices of the triangles.

# %%
# Apply affine transform calculated using srcTri and dstTri to src and output an image of size.
def apply_affine_transform(src, srcTri, dstTri, size) :
    
    # Given a pair of triangles, find the affine transform.
    warpMat = cv2.getAffineTransform(np.float32(srcTri), np.float32(dstTri))
    
    # Apply the Affine Transform just found to the src image
    dst = cv2.warpAffine(src, warpMat, (size[0], size[1]), None, flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_REFLECT_101)

    return dst

# Warps and alpha blends triangular regions from img1 and img2 to img
def morph_triangle(img1, img2, img, t1, t2, t, alpha) :

    # Find bounding rectangle for each triangle
    r1 = cv2.boundingRect(np.float32([t1]))
    r2 = cv2.boundingRect(np.float32([t2]))
    r = cv2.boundingRect(np.float32([t]))

    # Offset points by left top corner of the respective rectangles
    t1Rect = []
    t2Rect = []
    tRect = []

    for i in range(0, 3):
        tRect.append(((t[i][0] - r[0]),(t[i][1] - r[1])))
        t1Rect.append(((t1[i][0] - r1[0]),(t1[i][1] - r1[1])))
        t2Rect.append(((t2[i][0] - r2[0]),(t2[i][1] - r2[1])))

    # Get mask by filling triangle
    mask = np.zeros((r[3], r[2], 3), dtype = np.float32)
    cv2.fillConvexPoly(mask, np.int32(tRect), (1.0, 1.0, 1.0), 16, 0)

    # Apply warpImage to small rectangular patches
    img1Rect = img1[r1[1]:r1[1] + r1[3], r1[0]:r1[0] + r1[2]]
    img2Rect = img2[r2[1]:r2[1] + r2[3], r2[0]:r2[0] + r2[2]]

    size = (r[2], r[3])
    warpImage1 = apply_affine_transform(img1Rect, t1Rect, tRect, size)
    warpImage2 = apply_affine_transform(img2Rect, t2Rect, tRect, size)

    # Alpha blend rectangular patches
    imgRect = (1.0 - alpha) * warpImage1 + alpha * warpImage2

    # Copy triangular region of the rectangular patch to the output image
    #img[r[1]:r[1]+r[3], r[0]:r[0]+r[2]] = img[r[1]:r[1]+r[3], r[0]:r[0]+r[2]] * ( 1 - mask ) + imgRect * mask
    # === CORRECCIÓN PARA EL ERROR DE BROADCAST ===
    # Extraemos el parche de la imagen original en las coordenadas r
    img_patch = img[r[1]:r[1]+r[3], r[0]:r[0]+r[2]]
    
    # Aseguramos que la máscara, el parche deformado y el parche de destino tengan el mismo tamaño
    # usando las dimensiones del recorte destino (img_patch)
    h, w = img_patch.shape[:2]
    
    # Redimensionamos imgRect y mask al tamaño exacto de img_patch si hay discrepancias de 1 pixel
    if imgRect.shape[:2] != (h, w):
        imgRect = cv2.resize(imgRect, (w, h))
        mask = cv2.resize(mask, (w, h))
    
    # Aplicamos el Alpha blending final
    img[r[1]:r[1]+r[3], r[0]:r[0]+r[2]] = img_patch * (1 - mask) + imgRect * mask

# %% [markdown]
# ### **Create the Morph Sequence:** Finally, we can create the morph sequence by interpolating between the two warped images. This involves blending the two images together using a set of weights that range from 0 to 1. At each weight value, we calculate a weighted average of the two warped images, creating a series of intermediate images that blend the two original images together.

# %%
import os

def generate_single_morph(img1, img2, points1, points2, tri_list, alpha, output_filename):
    
    # Convertir a float
    img1 = np.float32(img1)
    img2 = np.float32(img2)

    # Calcular las coordenadas exactas al porcentaje (alpha) deseado
    points = []
    for i in range(0, len(points1)):
        x = (1 - alpha) * points1[i][0] + alpha * points2[i][0]
        y = (1 - alpha) * points1[i][1] + alpha * points2[i][1]
        points.append((x, y))
    
    # Crear lienzo en negro
    morphed_frame = np.zeros(img1.shape, dtype=img1.dtype)

    # Morfear cada triángulo
    for i in range(len(tri_list)):    
        x = int(tri_list[i][0])
        y = int(tri_list[i][1])
        z = int(tri_list[i][2])
        
        t1 = [points1[x], points1[y], points1[z]]
        t2 = [points2[x], points2[y], points2[z]]
        t = [points[x], points[y], points[z]]

        morph_triangle(img1, img2, morphed_frame, t1, t2, t, alpha)
        
    # Convertir de vuelta a formato de imagen y guardar
    imagen_final = np.uint8(morphed_frame)
    cv2.imwrite(output_filename, imagen_final)
    print(f"¡Imagen generada exitosamente en: {output_filename}!")

# %%
def doSingleMorphing(img1, img2, alpha, output_filename):
    [size, img1, img2, points1, points2, list3] = generate_face_correspondences(img1, img2)
    tri = make_delaunay(size[1], size[0], list3, img1, img2)
    generate_single_morph(img1, img2, points1, points2, tri, alpha, output_filename)

# %%
# 1. Crear una carpeta para mantener organizadas todas las imágenes generadas
carpeta_salida = "OpenCV_Morphing_FEI"
if not os.path.exists(carpeta_salida):
    os.makedirs(carpeta_salida)

porcentaje_mezcla = 0.5

# 2. Iterar sobre todos los pares posibles usando los índices de la lista
# Esto genera pares como (0, 1), (0, 2), (1, 2), etc.
for i, j in itertools.combinations(range(len(images)), 2):
    imagen_origen = images[i]
    imagen_destino = images[j]
    
    # Extraer los nombres originales (quitando el .jpg) para identificar el archivo final
    nombre_origen = image_names[i].split('.')[0]
    nombre_destino = image_names[j].split('.')[0]
    
    nombre_archivo_final = f"{carpeta_salida}/morph_{nombre_origen}_con_{nombre_destino}.jpg"
    
    print(f"Procesando mezcla: {nombre_origen} + {nombre_destino}...")
    
    # 3. Ejecutar la función con un bloque try-except para evitar que el script 
    # se detenga por completo si dlib no logra detectar un rostro en un par específico
    try:
        doSingleMorphing(imagen_origen, imagen_destino, porcentaje_mezcla, nombre_archivo_final)
    except Exception as e:
        print(f"Error al procesar {nombre_origen} y {nombre_destino}: {e}")

print("¡Procesamiento masivo completado!")
# Out:
# Procesando mezcla: 178a + 191a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_191a.jpg!
# Procesando mezcla: 178a + 194a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_194a.jpg!
# Procesando mezcla: 178a + 7a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_7a.jpg!
# Procesando mezcla: 178a + 131a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_131a.jpg!
# Procesando mezcla: 178a + 121a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_121a.jpg!
# Procesando mezcla: 178a + 68a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_68a.jpg!
# Procesando mezcla: 178a + 115a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_115a.jpg!
# Procesando mezcla: 178a + 164a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_164a.jpg!
# Procesando mezcla: 178a + 22a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_22a.jpg!
# Procesando mezcla: 178a + 172a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_172a.jpg!
# Procesando mezcla: 178a + 117a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_117a.jpg!
# Procesando mezcla: 178a + 14a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_14a.jpg!
# Procesando mezcla: 178a + 50a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_50a.jpg!
# Procesando mezcla: 178a + 167a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_167a.jpg!
# Procesando mezcla: 178a + 87a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_87a.jpg!
# Procesando mezcla: 178a + 163a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_163a.jpg!
# Procesando mezcla: 178a + 96a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_96a.jpg!
# Procesando mezcla: 178a + 62a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_62a.jpg!
# Procesando mezcla: 178a + 58a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_58a.jpg!
# Procesando mezcla: 178a + 11a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_11a.jpg!
# Procesando mezcla: 178a + 199a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_199a.jpg!
# Procesando mezcla: 178a + 173a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_173a.jpg!
# Procesando mezcla: 178a + 17a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_17a.jpg!
# Procesando mezcla: 178a + 64a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_64a.jpg!
# Procesando mezcla: 178a + 154a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_154a.jpg!
# Procesando mezcla: 178a + 12a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_12a.jpg!
# Procesando mezcla: 178a + 126a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_126a.jpg!
# Procesando mezcla: 178a + 188a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_188a.jpg!
# Procesando mezcla: 178a + 38a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_38a.jpg!
# Procesando mezcla: 178a + 47a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_47a.jpg!
# Procesando mezcla: 178a + 144a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_144a.jpg!
# Procesando mezcla: 178a + 136a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_136a.jpg!
# Procesando mezcla: 178a + 134a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_134a.jpg!
# Procesando mezcla: 178a + 152a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_152a.jpg!
# Procesando mezcla: 178a + 153a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_153a.jpg!
# Procesando mezcla: 178a + 141a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_141a.jpg!
# Procesando mezcla: 178a + 182a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_182a.jpg!
# Procesando mezcla: 178a + 133a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_133a.jpg!
# Procesando mezcla: 178a + 19a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_19a.jpg!
# Procesando mezcla: 178a + 166a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_166a.jpg!
# Procesando mezcla: 178a + 170a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_170a.jpg!
# Procesando mezcla: 178a + 79a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_79a.jpg!
# Procesando mezcla: 178a + 20a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_20a.jpg!
# Procesando mezcla: 178a + 186a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_186a.jpg!
# Procesando mezcla: 178a + 6a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_6a.jpg!
# Procesando mezcla: 178a + 86a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_86a.jpg!
# Procesando mezcla: 178a + 132a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_132a.jpg!
# Procesando mezcla: 178a + 175a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_175a.jpg!
# Procesando mezcla: 178a + 99a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_99a.jpg!
# Procesando mezcla: 178a + 93a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_93a.jpg!
# Procesando mezcla: 178a + 26a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_26a.jpg!
# Procesando mezcla: 178a + 119a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_119a.jpg!
# Procesando mezcla: 178a + 190a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_190a.jpg!
# Procesando mezcla: 178a + 71a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_71a.jpg!
# Procesando mezcla: 178a + 160a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_160a.jpg!
# Procesando mezcla: 178a + 54a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_54a.jpg!
# Procesando mezcla: 178a + 159a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_159a.jpg!
# Procesando mezcla: 178a + 73a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_73a.jpg!
# Procesando mezcla: 178a + 5a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_5a.jpg!
# Procesando mezcla: 178a + 142a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_142a.jpg!
# Procesando mezcla: 178a + 35a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_35a.jpg!
# Procesando mezcla: 178a + 90a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_90a.jpg!
# Procesando mezcla: 178a + 187a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_187a.jpg!
# Procesando mezcla: 178a + 55a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_55a.jpg!
# Procesando mezcla: 178a + 135a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_135a.jpg!
# Procesando mezcla: 178a + 3a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_3a.jpg!
# Procesando mezcla: 178a + 70a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_70a.jpg!
# Procesando mezcla: 178a + 81a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_81a.jpg!
# Procesando mezcla: 178a + 91a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_91a.jpg!
# Procesando mezcla: 178a + 151a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_151a.jpg!
# Procesando mezcla: 178a + 72a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_72a.jpg!
# Procesando mezcla: 178a + 171a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_171a.jpg!
# Procesando mezcla: 178a + 13a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_13a.jpg!
# Procesando mezcla: 178a + 195a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_195a.jpg!
# Procesando mezcla: 178a + 97a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_97a.jpg!
# Procesando mezcla: 178a + 181a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_181a.jpg!
# Procesando mezcla: 178a + 76a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_76a.jpg!
# Procesando mezcla: 178a + 98a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_98a.jpg!
# Procesando mezcla: 178a + 15a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_15a.jpg!
# Procesando mezcla: 178a + 43a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_43a.jpg!
# Procesando mezcla: 178a + 89a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_89a.jpg!
# Procesando mezcla: 178a + 41a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_41a.jpg!
# Procesando mezcla: 178a + 85a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_85a.jpg!
# Procesando mezcla: 178a + 88a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_88a.jpg!
# Procesando mezcla: 178a + 158a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_158a.jpg!
# Procesando mezcla: 178a + 179a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_179a.jpg!
# Procesando mezcla: 178a + 130a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_130a.jpg!
# Procesando mezcla: 178a + 180a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_180a.jpg!
# Procesando mezcla: 178a + 113a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_113a.jpg!
# Procesando mezcla: 178a + 57a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_57a.jpg!
# Procesando mezcla: 178a + 56a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_56a.jpg!
# Procesando mezcla: 178a + 138a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_138a.jpg!
# Procesando mezcla: 178a + 196a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_196a.jpg!
# Procesando mezcla: 178a + 145a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_145a.jpg!
# Procesando mezcla: 178a + 146a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_146a.jpg!
# Procesando mezcla: 178a + 200a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_200a.jpg!
# Procesando mezcla: 178a + 125a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_125a.jpg!
# Procesando mezcla: 178a + 27a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_27a.jpg!
# Procesando mezcla: 178a + 24a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_24a.jpg!
# Procesando mezcla: 178a + 112a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_112a.jpg!
# Procesando mezcla: 178a + 103a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_103a.jpg!
# Procesando mezcla: 178a + 66a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_66a.jpg!
# Procesando mezcla: 178a + 193a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_193a.jpg!
# Procesando mezcla: 178a + 137a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_137a.jpg!
# Procesando mezcla: 178a + 140a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_140a.jpg!
# Procesando mezcla: 178a + 61a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_61a.jpg!
# Procesando mezcla: 178a + 139a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_139a.jpg!
# Procesando mezcla: 178a + 48a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_48a.jpg!
# Procesando mezcla: 178a + 104a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_104a.jpg!
# Procesando mezcla: 178a + 31a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_31a.jpg!
# Procesando mezcla: 178a + 65a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_65a.jpg!
# Procesando mezcla: 178a + 198a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_198a.jpg!
# Procesando mezcla: 178a + 116a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_116a.jpg!
# Procesando mezcla: 178a + 92a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_92a.jpg!
# Procesando mezcla: 178a + 83a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_83a.jpg!
# Procesando mezcla: 178a + 127a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_127a.jpg!
# Procesando mezcla: 178a + 78a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_78a.jpg!
# Procesando mezcla: 178a + 52a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_52a.jpg!
# Procesando mezcla: 178a + 114a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_114a.jpg!
# Procesando mezcla: 178a + 32a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_32a.jpg!
# Procesando mezcla: 178a + 77a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_77a.jpg!
# Procesando mezcla: 178a + 37a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_37a.jpg!
# Procesando mezcla: 178a + 51a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_51a.jpg!
# Procesando mezcla: 178a + 9a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_9a.jpg!
# Procesando mezcla: 178a + 82a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_82a.jpg!
# Procesando mezcla: 178a + 192a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_192a.jpg!
# Procesando mezcla: 178a + 53a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_53a.jpg!
# Procesando mezcla: 178a + 124a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_124a.jpg!
# Procesando mezcla: 178a + 109a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_109a.jpg!
# Procesando mezcla: 178a + 177a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_177a.jpg!
# Procesando mezcla: 178a + 162a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_162a.jpg!
# Procesando mezcla: 178a + 1a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_1a.jpg!
# Procesando mezcla: 178a + 184a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_184a.jpg!
# Procesando mezcla: 178a + 150a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_150a.jpg!
# Procesando mezcla: 178a + 49a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_49a.jpg!
# Procesando mezcla: 178a + 42a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_42a.jpg!
# Procesando mezcla: 178a + 156a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_156a.jpg!
# Procesando mezcla: 178a + 168a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_168a.jpg!
# Procesando mezcla: 178a + 10a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_10a.jpg!
# Procesando mezcla: 178a + 23a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_23a.jpg!
# Procesando mezcla: 178a + 75a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_75a.jpg!
# Procesando mezcla: 178a + 59a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_59a.jpg!
# Procesando mezcla: 178a + 120a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_120a.jpg!
# Procesando mezcla: 178a + 95a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_95a.jpg!
# Procesando mezcla: 178a + 155a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_155a.jpg!
# Procesando mezcla: 178a + 69a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_69a.jpg!
# Procesando mezcla: 178a + 16a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_16a.jpg!
# Procesando mezcla: 178a + 165a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_165a.jpg!
# Procesando mezcla: 178a + 169a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_169a.jpg!
# Procesando mezcla: 178a + 80a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_80a.jpg!
# Procesando mezcla: 178a + 122a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_122a.jpg!
# Procesando mezcla: 178a + 30a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_30a.jpg!
# Procesando mezcla: 178a + 107a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_107a.jpg!
# Procesando mezcla: 178a + 45a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_45a.jpg!
# Procesando mezcla: 178a + 157a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_157a.jpg!
# Procesando mezcla: 178a + 102a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_102a.jpg!
# Procesando mezcla: 178a + 74a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_74a.jpg!
# Procesando mezcla: 178a + 185a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_185a.jpg!
# Procesando mezcla: 178a + 174a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_174a.jpg!
# Procesando mezcla: 178a + 44a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_44a.jpg!
# Procesando mezcla: 178a + 25a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_25a.jpg!
# Procesando mezcla: 178a + 105a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_105a.jpg!
# Procesando mezcla: 178a + 108a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_108a.jpg!
# Procesando mezcla: 178a + 28a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_28a.jpg!
# Procesando mezcla: 178a + 176a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_176a.jpg!
# Procesando mezcla: 178a + 106a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_106a.jpg!
# Procesando mezcla: 178a + 128a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_128a.jpg!
# Procesando mezcla: 178a + 84a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_84a.jpg!
# Procesando mezcla: 178a + 60a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_60a.jpg!
# Procesando mezcla: 178a + 2a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_2a.jpg!
# Procesando mezcla: 178a + 21a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_21a.jpg!
# Procesando mezcla: 178a + 40a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_40a.jpg!
# Procesando mezcla: 178a + 129a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_129a.jpg!
# Procesando mezcla: 178a + 63a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_63a.jpg!
# Procesando mezcla: 178a + 189a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_189a.jpg!
# Procesando mezcla: 178a + 197a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_197a.jpg!
# Procesando mezcla: 178a + 29a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_29a.jpg!
# Procesando mezcla: 178a + 67a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_67a.jpg!
# Procesando mezcla: 178a + 161a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_161a.jpg!
# Procesando mezcla: 178a + 18a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_18a.jpg!
# Procesando mezcla: 178a + 94a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_94a.jpg!
# Procesando mezcla: 178a + 101a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_101a.jpg!
# Procesando mezcla: 178a + 34a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_34a.jpg!
# Procesando mezcla: 178a + 8a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_8a.jpg!
# Procesando mezcla: 178a + 36a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_36a.jpg!
# Procesando mezcla: 178a + 4a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_4a.jpg!
# Procesando mezcla: 178a + 111a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_111a.jpg!
# Procesando mezcla: 178a + 148a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_148a.jpg!
# Procesando mezcla: 178a + 123a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_123a.jpg!
# Procesando mezcla: 178a + 100a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_100a.jpg!
# Procesando mezcla: 178a + 33a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_33a.jpg!
# Procesando mezcla: 178a + 118a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_118a.jpg!
# Procesando mezcla: 178a + 110a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_110a.jpg!
# Procesando mezcla: 178a + 143a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_143a.jpg!
# Procesando mezcla: 178a + 147a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_147a.jpg!
# Procesando mezcla: 178a + 183a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_183a.jpg!
# Procesando mezcla: 178a + 46a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_46a.jpg!
# Procesando mezcla: 178a + 39a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_39a.jpg!
# Procesando mezcla: 178a + 149a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_178a_con_149a.jpg!
# Procesando mezcla: 191a + 194a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_194a.jpg!
# Procesando mezcla: 191a + 7a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_7a.jpg!
# Procesando mezcla: 191a + 131a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_131a.jpg!
# Procesando mezcla: 191a + 121a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_121a.jpg!
# Procesando mezcla: 191a + 68a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_68a.jpg!
# Procesando mezcla: 191a + 115a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_115a.jpg!
# Procesando mezcla: 191a + 164a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_164a.jpg!
# Procesando mezcla: 191a + 22a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_22a.jpg!
# Procesando mezcla: 191a + 172a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_172a.jpg!
# Procesando mezcla: 191a + 117a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_117a.jpg!
# Procesando mezcla: 191a + 14a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_14a.jpg!
# Procesando mezcla: 191a + 50a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_50a.jpg!
# Procesando mezcla: 191a + 167a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_167a.jpg!
# Procesando mezcla: 191a + 87a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_87a.jpg!
# Procesando mezcla: 191a + 163a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_163a.jpg!
# Procesando mezcla: 191a + 96a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_96a.jpg!
# Procesando mezcla: 191a + 62a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_62a.jpg!
# Procesando mezcla: 191a + 58a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_58a.jpg!
# Procesando mezcla: 191a + 11a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_11a.jpg!
# Procesando mezcla: 191a + 199a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_199a.jpg!
# Procesando mezcla: 191a + 173a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_173a.jpg!
# Procesando mezcla: 191a + 17a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_17a.jpg!
# Procesando mezcla: 191a + 64a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_64a.jpg!
# Procesando mezcla: 191a + 154a...
# Error al procesar 191a y 154a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 12a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_12a.jpg!
# Procesando mezcla: 191a + 126a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_126a.jpg!
# Procesando mezcla: 191a + 188a...
# Error al procesar 191a y 188a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 38a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_38a.jpg!
# Procesando mezcla: 191a + 47a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_47a.jpg!
# Procesando mezcla: 191a + 144a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_144a.jpg!
# Procesando mezcla: 191a + 136a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_136a.jpg!
# Procesando mezcla: 191a + 134a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_134a.jpg!
# Procesando mezcla: 191a + 152a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_152a.jpg!
# Procesando mezcla: 191a + 153a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_153a.jpg!
# Procesando mezcla: 191a + 141a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_141a.jpg!
# Procesando mezcla: 191a + 182a...
# Error al procesar 191a y 182a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 133a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_133a.jpg!
# Procesando mezcla: 191a + 19a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_19a.jpg!
# Procesando mezcla: 191a + 166a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_166a.jpg!
# Procesando mezcla: 191a + 170a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_170a.jpg!
# Procesando mezcla: 191a + 79a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_79a.jpg!
# Procesando mezcla: 191a + 20a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_20a.jpg!
# Procesando mezcla: 191a + 186a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_186a.jpg!
# Procesando mezcla: 191a + 6a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_6a.jpg!
# Procesando mezcla: 191a + 86a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_86a.jpg!
# Procesando mezcla: 191a + 132a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_132a.jpg!
# Procesando mezcla: 191a + 175a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_175a.jpg!
# Procesando mezcla: 191a + 99a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_99a.jpg!
# Procesando mezcla: 191a + 93a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_93a.jpg!
# Procesando mezcla: 191a + 26a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_26a.jpg!
# Procesando mezcla: 191a + 119a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_119a.jpg!
# Procesando mezcla: 191a + 190a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_190a.jpg!
# Procesando mezcla: 191a + 71a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_71a.jpg!
# Procesando mezcla: 191a + 160a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_160a.jpg!
# Procesando mezcla: 191a + 54a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_54a.jpg!
# Procesando mezcla: 191a + 159a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_159a.jpg!
# Procesando mezcla: 191a + 73a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_73a.jpg!
# Procesando mezcla: 191a + 5a...
# Error al procesar 191a y 5a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 142a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_142a.jpg!
# Procesando mezcla: 191a + 35a...
# Error al procesar 191a y 35a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 90a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_90a.jpg!
# Procesando mezcla: 191a + 187a...
# Error al procesar 191a y 187a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 55a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_55a.jpg!
# Procesando mezcla: 191a + 135a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_135a.jpg!
# Procesando mezcla: 191a + 3a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_3a.jpg!
# Procesando mezcla: 191a + 70a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_70a.jpg!
# Procesando mezcla: 191a + 81a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_81a.jpg!
# Procesando mezcla: 191a + 91a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_91a.jpg!
# Procesando mezcla: 191a + 151a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_151a.jpg!
# Procesando mezcla: 191a + 72a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_72a.jpg!
# Procesando mezcla: 191a + 171a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_171a.jpg!
# Procesando mezcla: 191a + 13a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_13a.jpg!
# Procesando mezcla: 191a + 195a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_195a.jpg!
# Procesando mezcla: 191a + 97a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_97a.jpg!
# Procesando mezcla: 191a + 181a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_181a.jpg!
# Procesando mezcla: 191a + 76a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_76a.jpg!
# Procesando mezcla: 191a + 98a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_98a.jpg!
# Procesando mezcla: 191a + 15a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_15a.jpg!
# Procesando mezcla: 191a + 43a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_43a.jpg!
# Procesando mezcla: 191a + 89a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_89a.jpg!
# Procesando mezcla: 191a + 41a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_41a.jpg!
# Procesando mezcla: 191a + 85a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_85a.jpg!
# Procesando mezcla: 191a + 88a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_88a.jpg!
# Procesando mezcla: 191a + 158a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_158a.jpg!
# Procesando mezcla: 191a + 179a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_179a.jpg!
# Procesando mezcla: 191a + 130a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_130a.jpg!
# Procesando mezcla: 191a + 180a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_180a.jpg!
# Procesando mezcla: 191a + 113a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_113a.jpg!
# Procesando mezcla: 191a + 57a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_57a.jpg!
# Procesando mezcla: 191a + 56a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_56a.jpg!
# Procesando mezcla: 191a + 138a...
# Error al procesar 191a y 138a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 196a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_196a.jpg!
# Procesando mezcla: 191a + 145a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_145a.jpg!
# Procesando mezcla: 191a + 146a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_146a.jpg!
# Procesando mezcla: 191a + 200a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_200a.jpg!
# Procesando mezcla: 191a + 125a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_125a.jpg!
# Procesando mezcla: 191a + 27a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_27a.jpg!
# Procesando mezcla: 191a + 24a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_24a.jpg!
# Procesando mezcla: 191a + 112a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_112a.jpg!
# Procesando mezcla: 191a + 103a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_103a.jpg!
# Procesando mezcla: 191a + 66a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_66a.jpg!
# Procesando mezcla: 191a + 193a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_193a.jpg!
# Procesando mezcla: 191a + 137a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_137a.jpg!
# Procesando mezcla: 191a + 140a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_140a.jpg!
# Procesando mezcla: 191a + 61a...
# Error al procesar 191a y 61a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 139a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_139a.jpg!
# Procesando mezcla: 191a + 48a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_48a.jpg!
# Procesando mezcla: 191a + 104a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_104a.jpg!
# Procesando mezcla: 191a + 31a...
# Error al procesar 191a y 31a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 65a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_65a.jpg!
# Procesando mezcla: 191a + 198a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_198a.jpg!
# Procesando mezcla: 191a + 116a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_116a.jpg!
# Procesando mezcla: 191a + 92a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_92a.jpg!
# Procesando mezcla: 191a + 83a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_83a.jpg!
# Procesando mezcla: 191a + 127a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_127a.jpg!
# Procesando mezcla: 191a + 78a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_78a.jpg!
# Procesando mezcla: 191a + 52a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_52a.jpg!
# Procesando mezcla: 191a + 114a...
# Error al procesar 191a y 114a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 32a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_32a.jpg!
# Procesando mezcla: 191a + 77a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_77a.jpg!
# Procesando mezcla: 191a + 37a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_37a.jpg!
# Procesando mezcla: 191a + 51a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_51a.jpg!
# Procesando mezcla: 191a + 9a...
# Error al procesar 191a y 9a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 82a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_82a.jpg!
# Procesando mezcla: 191a + 192a...
# Error al procesar 191a y 192a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 53a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_53a.jpg!
# Procesando mezcla: 191a + 124a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_124a.jpg!
# Procesando mezcla: 191a + 109a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_109a.jpg!
# Procesando mezcla: 191a + 177a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_177a.jpg!
# Procesando mezcla: 191a + 162a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_162a.jpg!
# Procesando mezcla: 191a + 1a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_1a.jpg!
# Procesando mezcla: 191a + 184a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_184a.jpg!
# Procesando mezcla: 191a + 150a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_150a.jpg!
# Procesando mezcla: 191a + 49a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_49a.jpg!
# Procesando mezcla: 191a + 42a...
# Error al procesar 191a y 42a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 156a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_156a.jpg!
# Procesando mezcla: 191a + 168a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_168a.jpg!
# Procesando mezcla: 191a + 10a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_10a.jpg!
# Procesando mezcla: 191a + 23a...
# Error al procesar 191a y 23a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 75a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_75a.jpg!
# Procesando mezcla: 191a + 59a...
# Error al procesar 191a y 59a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 120a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_120a.jpg!
# Procesando mezcla: 191a + 95a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_95a.jpg!
# Procesando mezcla: 191a + 155a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_155a.jpg!
# Procesando mezcla: 191a + 69a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_69a.jpg!
# Procesando mezcla: 191a + 16a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_16a.jpg!
# Procesando mezcla: 191a + 165a...
# Error al procesar 191a y 165a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 169a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_169a.jpg!
# Procesando mezcla: 191a + 80a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_80a.jpg!
# Procesando mezcla: 191a + 122a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_122a.jpg!
# Procesando mezcla: 191a + 30a...
# Error al procesar 191a y 30a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 107a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_107a.jpg!
# Procesando mezcla: 191a + 45a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_45a.jpg!
# Procesando mezcla: 191a + 157a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_157a.jpg!
# Procesando mezcla: 191a + 102a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_102a.jpg!
# Procesando mezcla: 191a + 74a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_74a.jpg!
# Procesando mezcla: 191a + 185a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_185a.jpg!
# Procesando mezcla: 191a + 174a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_174a.jpg!
# Procesando mezcla: 191a + 44a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_44a.jpg!
# Procesando mezcla: 191a + 25a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_25a.jpg!
# Procesando mezcla: 191a + 105a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_105a.jpg!
# Procesando mezcla: 191a + 108a...
# Error al procesar 191a y 108a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 28a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_28a.jpg!
# Procesando mezcla: 191a + 176a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_176a.jpg!
# Procesando mezcla: 191a + 106a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_106a.jpg!
# Procesando mezcla: 191a + 128a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_128a.jpg!
# Procesando mezcla: 191a + 84a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_84a.jpg!
# Procesando mezcla: 191a + 60a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_60a.jpg!
# Procesando mezcla: 191a + 2a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_2a.jpg!
# Procesando mezcla: 191a + 21a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_21a.jpg!
# Procesando mezcla: 191a + 40a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_40a.jpg!
# Procesando mezcla: 191a + 129a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_129a.jpg!
# Procesando mezcla: 191a + 63a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_63a.jpg!
# Procesando mezcla: 191a + 189a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_189a.jpg!
# Procesando mezcla: 191a + 197a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_197a.jpg!
# Procesando mezcla: 191a + 29a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_29a.jpg!
# Procesando mezcla: 191a + 67a...
# Error al procesar 191a y 67a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 161a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_161a.jpg!
# Procesando mezcla: 191a + 18a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_18a.jpg!
# Procesando mezcla: 191a + 94a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_94a.jpg!
# Procesando mezcla: 191a + 101a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_101a.jpg!
# Procesando mezcla: 191a + 34a...
# Error al procesar 191a y 34a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 8a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_8a.jpg!
# Procesando mezcla: 191a + 36a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_36a.jpg!
# Procesando mezcla: 191a + 4a...
# Error al procesar 191a y 4a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 111a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_111a.jpg!
# Procesando mezcla: 191a + 148a...
# Error al procesar 191a y 148a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 123a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_123a.jpg!
# Procesando mezcla: 191a + 100a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_100a.jpg!
# Procesando mezcla: 191a + 33a...
# Error al procesar 191a y 33a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 118a...
# Error al procesar 191a y 118a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 191a + 110a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_110a.jpg!
# Procesando mezcla: 191a + 143a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_143a.jpg!
# Procesando mezcla: 191a + 147a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_147a.jpg!
# Procesando mezcla: 191a + 183a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_183a.jpg!
# Procesando mezcla: 191a + 46a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_46a.jpg!
# Procesando mezcla: 191a + 39a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_191a_con_39a.jpg!
# Procesando mezcla: 191a + 149a...
# Error al procesar 191a y 149a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 194a + 7a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_194a_con_7a.jpg!
# Procesando mezcla: 194a + 131a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_194a_con_131a.jpg!
# Procesando mezcla: 194a + 121a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_194a_con_121a.jpg!
# Procesando mezcla: 194a + 68a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_194a_con_68a.jpg!
# Procesando mezcla: 194a + 115a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_194a_con_115a.jpg!
# Procesando mezcla: 194a + 164a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_194a_con_164a.jpg!
# Procesando mezcla: 194a + 22a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_194a_con_22a.jpg!
# Procesando mezcla: 194a + 172a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_194a_con_172a.jpg!
# Procesando mezcla: 194a + 117a...
# ...
# Procesando mezcla: 122a + 161a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_161a.jpg!
# Procesando mezcla: 122a + 18a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_18a.jpg!
# Procesando mezcla: 122a + 94a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_94a.jpg!
# Procesando mezcla: 122a + 101a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_101a.jpg!
# Procesando mezcla: 122a + 34a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_34a.jpg!
# Procesando mezcla: 122a + 8a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_8a.jpg!
# Procesando mezcla: 122a + 36a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_36a.jpg!
# Procesando mezcla: 122a + 4a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_4a.jpg!
# Procesando mezcla: 122a + 111a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_111a.jpg!
# Procesando mezcla: 122a + 148a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_148a.jpg!
# Procesando mezcla: 122a + 123a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_123a.jpg!
# Procesando mezcla: 122a + 100a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_100a.jpg!
# Procesando mezcla: 122a + 33a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_33a.jpg!
# Procesando mezcla: 122a + 118a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_118a.jpg!
# Procesando mezcla: 122a + 110a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_110a.jpg!
# Procesando mezcla: 122a + 143a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_143a.jpg!
# Procesando mezcla: 122a + 147a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_147a.jpg!
# Procesando mezcla: 122a + 183a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_183a.jpg!
# Procesando mezcla: 122a + 46a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_46a.jpg!
# Procesando mezcla: 122a + 39a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_39a.jpg!
# Procesando mezcla: 122a + 149a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_122a_con_149a.jpg!
# Procesando mezcla: 30a + 107a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_107a.jpg!
# Procesando mezcla: 30a + 45a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_45a.jpg!
# Procesando mezcla: 30a + 157a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_157a.jpg!
# Procesando mezcla: 30a + 102a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_102a.jpg!
# Procesando mezcla: 30a + 74a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_74a.jpg!
# Procesando mezcla: 30a + 185a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_185a.jpg!
# Procesando mezcla: 30a + 174a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_174a.jpg!
# Procesando mezcla: 30a + 44a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_44a.jpg!
# Procesando mezcla: 30a + 25a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_25a.jpg!
# Procesando mezcla: 30a + 105a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_105a.jpg!
# Procesando mezcla: 30a + 108a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_108a.jpg!
# Procesando mezcla: 30a + 28a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_28a.jpg!
# Procesando mezcla: 30a + 176a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_176a.jpg!
# Procesando mezcla: 30a + 106a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_106a.jpg!
# Procesando mezcla: 30a + 128a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_128a.jpg!
# Procesando mezcla: 30a + 84a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_84a.jpg!
# Procesando mezcla: 30a + 60a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_60a.jpg!
# Procesando mezcla: 30a + 2a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_2a.jpg!
# Procesando mezcla: 30a + 21a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_21a.jpg!
# Procesando mezcla: 30a + 40a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_40a.jpg!
# Procesando mezcla: 30a + 129a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_129a.jpg!
# Procesando mezcla: 30a + 63a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_63a.jpg!
# Procesando mezcla: 30a + 189a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_189a.jpg!
# Procesando mezcla: 30a + 197a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_197a.jpg!
# Procesando mezcla: 30a + 29a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_29a.jpg!
# Procesando mezcla: 30a + 67a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_67a.jpg!
# Procesando mezcla: 30a + 161a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_161a.jpg!
# Procesando mezcla: 30a + 18a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_18a.jpg!
# Procesando mezcla: 30a + 94a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_94a.jpg!
# Procesando mezcla: 30a + 101a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_101a.jpg!
# Procesando mezcla: 30a + 34a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_34a.jpg!
# Procesando mezcla: 30a + 8a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_8a.jpg!
# Procesando mezcla: 30a + 36a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_36a.jpg!
# Procesando mezcla: 30a + 4a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_4a.jpg!
# Procesando mezcla: 30a + 111a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_111a.jpg!
# Procesando mezcla: 30a + 148a...
# Error al procesar 30a y 148a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 30a + 123a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_123a.jpg!
# Procesando mezcla: 30a + 100a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_100a.jpg!
# Procesando mezcla: 30a + 33a...
# Error al procesar 30a y 33a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 30a + 118a...
# Error al procesar 30a y 118a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 30a + 110a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_110a.jpg!
# Procesando mezcla: 30a + 143a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_143a.jpg!
# Procesando mezcla: 30a + 147a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_147a.jpg!
# Procesando mezcla: 30a + 183a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_183a.jpg!
# Procesando mezcla: 30a + 46a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_46a.jpg!
# Procesando mezcla: 30a + 39a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_30a_con_39a.jpg!
# Procesando mezcla: 30a + 149a...
# Error al procesar 30a y 149a: OpenCV(5.0.0) /io/opencv/modules/geometry/src/subdivision2d.cpp:298: error: (-211:One of the arguments' values is out of range)  in function 'locate'
#
# Procesando mezcla: 107a + 45a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_45a.jpg!
# Procesando mezcla: 107a + 157a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_157a.jpg!
# Procesando mezcla: 107a + 102a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_102a.jpg!
# Procesando mezcla: 107a + 74a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_74a.jpg!
# Procesando mezcla: 107a + 185a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_185a.jpg!
# Procesando mezcla: 107a + 174a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_174a.jpg!
# Procesando mezcla: 107a + 44a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_44a.jpg!
# Procesando mezcla: 107a + 25a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_25a.jpg!
# Procesando mezcla: 107a + 105a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_105a.jpg!
# Procesando mezcla: 107a + 108a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_108a.jpg!
# Procesando mezcla: 107a + 28a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_28a.jpg!
# Procesando mezcla: 107a + 176a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_176a.jpg!
# Procesando mezcla: 107a + 106a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_106a.jpg!
# Procesando mezcla: 107a + 128a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_128a.jpg!
# Procesando mezcla: 107a + 84a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_84a.jpg!
# Procesando mezcla: 107a + 60a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_60a.jpg!
# Procesando mezcla: 107a + 2a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_2a.jpg!
# Procesando mezcla: 107a + 21a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_21a.jpg!
# Procesando mezcla: 107a + 40a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_40a.jpg!
# Procesando mezcla: 107a + 129a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_129a.jpg!
# Procesando mezcla: 107a + 63a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_63a.jpg!
# Procesando mezcla: 107a + 189a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_189a.jpg!
# Procesando mezcla: 107a + 197a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_197a.jpg!
# Procesando mezcla: 107a + 29a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_29a.jpg!
# Procesando mezcla: 107a + 67a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_67a.jpg!
# Procesando mezcla: 107a + 161a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_161a.jpg!
# Procesando mezcla: 107a + 18a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_18a.jpg!
# Procesando mezcla: 107a + 94a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_94a.jpg!
# Procesando mezcla: 107a + 101a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_101a.jpg!
# Procesando mezcla: 107a + 34a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_34a.jpg!
# Procesando mezcla: 107a + 8a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_8a.jpg!
# Procesando mezcla: 107a + 36a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_36a.jpg!
# Procesando mezcla: 107a + 4a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_4a.jpg!
# Procesando mezcla: 107a + 111a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_111a.jpg!
# Procesando mezcla: 107a + 148a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_148a.jpg!
# Procesando mezcla: 107a + 123a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_123a.jpg!
# Procesando mezcla: 107a + 100a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_100a.jpg!
# Procesando mezcla: 107a + 33a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_33a.jpg!
# Procesando mezcla: 107a + 118a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_118a.jpg!
# Procesando mezcla: 107a + 110a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_110a.jpg!
# Procesando mezcla: 107a + 143a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_143a.jpg!
# Procesando mezcla: 107a + 147a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_147a.jpg!
# Procesando mezcla: 107a + 183a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_183a.jpg!
# Procesando mezcla: 107a + 46a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_46a.jpg!
# Procesando mezcla: 107a + 39a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_39a.jpg!
# Procesando mezcla: 107a + 149a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_107a_con_149a.jpg!
# Procesando mezcla: 45a + 157a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_157a.jpg!
# Procesando mezcla: 45a + 102a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_102a.jpg!
# Procesando mezcla: 45a + 74a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_74a.jpg!
# Procesando mezcla: 45a + 185a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_185a.jpg!
# Procesando mezcla: 45a + 174a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_174a.jpg!
# Procesando mezcla: 45a + 44a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_44a.jpg!
# Procesando mezcla: 45a + 25a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_25a.jpg!
# Procesando mezcla: 45a + 105a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_105a.jpg!
# Procesando mezcla: 45a + 108a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_108a.jpg!
# Procesando mezcla: 45a + 28a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_28a.jpg!
# Procesando mezcla: 45a + 176a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_176a.jpg!
# Procesando mezcla: 45a + 106a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_106a.jpg!
# Procesando mezcla: 45a + 128a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_128a.jpg!
# Procesando mezcla: 45a + 84a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_84a.jpg!
# Procesando mezcla: 45a + 60a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_60a.jpg!
# Procesando mezcla: 45a + 2a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_2a.jpg!
# Procesando mezcla: 45a + 21a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_21a.jpg!
# Procesando mezcla: 45a + 40a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_40a.jpg!
# Procesando mezcla: 45a + 129a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_129a.jpg!
# Procesando mezcla: 45a + 63a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_63a.jpg!
# Procesando mezcla: 45a + 189a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_189a.jpg!
# Procesando mezcla: 45a + 197a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_197a.jpg!
# Procesando mezcla: 45a + 29a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_29a.jpg!
# Procesando mezcla: 45a + 67a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_67a.jpg!
# Procesando mezcla: 45a + 161a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_161a.jpg!
# Procesando mezcla: 45a + 18a...
# ¡Imagen generada exitosamente en: OpenCV_Morphing_FEI/morph_45a_con_18a.jpg!
# Procesando mezcla: 45a + 94a...
